# %%
# TypeCasting >> The process of changing the data type of  a value / object
# why? while executing / computation using operators, there can be mismatch between the data type.

a = 7
type(a)
# Out:
# int

# %%
b = "Priya"
type(b)
# Out:
# str

# %%
3+5
# Out:
# 8

# %%
a = "2"
b = 3
(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 a = "2"
#       2 b = 3
# ----> 3 (a+b)
#
# TypeError: can only concatenate str (not "int") to str

# %%
#String to integer
a = "2"
b = 3
print (type(a))
print (type(int(a)))
int(a) + b
# Out:
# <class 'str'>
# <class 'int'>
# 5

# %%
# float to integer
a = 4.3
int(a)
# Out:
# 4

# %%
# integer to float
b = 8 
float(b)
# Out:
# 8.0

# %%
#String to float
c = "5.4"
float(c)
# Out:
# 5.4

# %%
#Character cannot be converted into numbers
d = "Ajay"
int(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 3
#       1 #Character cannot be converted into numbers
#       2 d = "Ajay"
# ----> 3 int(d)
#
# ValueError: invalid literal for int() with base 10: 'Ajay'

# %%
#Integer to String
e = 6
str(e)
# Out:
# '6'

# %%
#TypeCasting is of two types >> explicit and implicit

#Implicit typecasting >> python understands the data type
 
a = 5
type(a)
# Out:
# int

# %%
2 + 3.4
# Out:
# 5.4

# %%
#Explicit typecasting >> Convert data type using in built function >> str, int, float, bool

a = "2"
print (type(a))
int(a)
# Out:
# <class 'str'>
# 2

# %%
a = "Ajay"
b = 5
a + b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 a = "Ajay"
#       2 b = 5
# ----> 3 a + b
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Concatenation >> combining strings

a = "Ajay"
b = " Kumar Gupta"
a+b
# Out:
# 'Ajay Kumar Gupta'

# %%
#TypeCasting into bool

bool(0)
# Out:
# False

# %%
bool(100)
# Out:
# True

# %%
bool(-8)
# Out:
# True

# %%
bool("")   #Empty String
# Out:
# False
