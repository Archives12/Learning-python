# %%
#Variable or identifier ->> placeholders where we keep variety of data which can use to write logic 
#Variables is a reserved memory space for storing values.
#Variables can be started with underscore or alphabet. 
#Variables cannot be keyword.

c = "Ajay"

# %%
c
# Out:
# 'Ajay'

# %%
type(c)
# Out:
# str

# %%
True-False
# Out:
# 1

# %%
True*False
# Out:
# 0

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
f = None
f

# %%
type(f)
# Out:
# NoneType

# %%
# x+iy >> complex number

com = 5 + 6j

type(com)
# Out:
# complex

# %%
com.real
# Out:
# 5.0

# %%
com.imag
# Out:
# 6.0

# %%
#Multiple line comment
# ''' --> single quote
# """ --> double quote

# %%
# Keywords --> predefined words that hold a special meaning and have specific purpose in python

help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
# Statement >> fundamental block of code
''' Statement can be of many type >> expression, assignment, conditional statement,loop'''

# input output >> if you want some user to give value of variable 

name = input("please enter your name")

# %%
print(name)
# Out:
# Priya

# %%
type(name)
# Out:
# str
