# %%
#Conditional statement >>helps you to code decisions based on some preconditions.

#if
#if else
#if elif else
#nested if else

# %%
3 > 4
# Out:
# False

# %%
a = 100
if a > 0:  #execute the if block, if the condition is true
    print("The number is greater than 0")
# Out:
# The number is greater than 0

# %%
weather= 'rainy'
if weather == 'rainy' : 
    print('I will not play cricket')    # identation is necessary
# Out:
# I will not play cricket

# %%
weather= 'rainy'
if weather == 'rainy' : 
print('I will not play cricket')
# Out:
#   Cell In[9], line 3
#     print('I will not play cricket')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
temp = 30
if temp > 25:
    print("room temp")
# Out:
# room temp

# %%
is_ds_course = True
if is_ds_course:
    print("I am studying the course")
# Out:
# I am studying the course

# %%
grade = 8
if grade >= 8:
    print("You are excellent")

# %%
number = 42
if ((number % 2 == 0) & (number > 0)):
    print("This is the number of the interest")
# Out:
# This is the number of the interest

# %%
# in real life, decisions are made based on multiple conditions
# in real life if one condition is not fulfilled, you will do something else.

# if else >> execute the if block, when the condition is true else execute else block

# %%
weather = "sunny"
if weather == "sunny":          #condition is true, executes if block
    print("I will play cricket")
else:                         # condition is not true, else block will be executed
    print("I will watch TV")
# Out:
# I will play cricket

# %%
age = 15
if age >= 18:
    print("You will be served alcohol")
else:
    print("get out of the bar")
# Out:
# get out of the bar

# %%
age = 5
if age >= 18:
    print("Please have a driving license and drive")
else:
    print("don't drive")
# Out:
# don't drive

# %%
# to check if a number is even

num = 45
if num % 2 == 0:
    print("even")
else:
    print("odd")
# Out:
# odd

# %%
score = 75
if score >= 90:
    print("grade A")
elif (80<= score < 90):
    print("grade B")
elif (70<= score<80):
    print("grade C")
else:
    print("grade D")
# Out:
# grade C

# %%
is_vip = True
age = 70
if is_vip:
    if age >= 18:
        if age < 65:
            print("welcome to vip customer")
        else:
            print("You are vip and very important. You are eligible for senior citizen discount")
    else:
        print("vip status is only for adult")
else: 
    print("You are not a vip customer and will be charged a regular price")
# Out:
# You are vip and very important. You are eligible for senior citizen discount

# %%
a = input("Enter a number")         #by default input treats everything as string
print("The number is",a)
# Out:
# The number is 554

# %%
type(a)
# Out:
# str

# %%
a = int(input("Enter a number"))
print("The number is", a)
if a >= 100:
    print("The number is greater than 100")
elif 0 <= a < 100:
    print("The number is greater than 0 and less than 100")
else:
    print("This is a negative number")
# Out:
# The number is 56
# The number is greater than 0 and less than 100

# %%
a = "Sam"
len(a)
# Out:
# 3

# %%
name = input("Please enter your name")
email = input("Please enter your email")
password = input("Please enter your password")

if name == "":
    print("Please enter a valid name, cannot be empty")
else:
    if "@" not in email:
        print("Please enter a valid email")
    else:
        if len(password) < 0:
            print("No password entered, pls provide valid password")
        else:
            print("Login/registration is successful")
# Out:
# Login/registration is successful
