# %%
#mode
#r>> read mode
#w >> write mode
#a >> append mode
#r+ >> both reading and writing

# %%
open("file.txt",'r') #if there is no any file, and u open it in read mode it will throw an error
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 open("file.txt",'r') #if there is no any file, and u open it in read mode it will throw an error
#
# FileNotFoundError: [Errno 2] No such file or directory: 'file.txt'

# %%
file = open("file.txt",'w') #w >> write mode, if a file is not there it will create the file.txt and then write

file.write("Hello this is my first line in the text file") #number below is number of bytes you have written
# Out:
# 44

# %%
#as of now if u open the written file you will not be able to see any text file
#in order to see u have to close the file

file.close()

# %%
file  #file attributes
# Out:
# <_io.TextIOWrapper name='file.txt' mode='w' encoding='cp1252'>

# %%
g
# Out:
# True

# %%
file = open("file.txt","r")

# %%
file.closed
# Out:
# False

# %%
file.close()

# %%
file.closed
# Out:
# True

# %%
file.name
# Out:
# 'file.txt'

# %%
file.mode
# Out:
# 'r'

# %%
file.closed
# Out:
# True

# %%
file.write("This is my Second line")   #this will not be executed throw an error>> file is closed >> you cannot write, anything in closed file
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 file.write("This is my Second line")   #this will not be executed throw an error>> file is closed >> you cannot write, anything in closed file
#
# ValueError: I/O operation on closed file.

# %%
file = open("file.txt","w")         #It will truncate(delete) all earlier content and make a fresh file

# %%
file.close()

# %%
file = open("file.txt","w")
file.write("This is my first line")
file.write("This is my second line")
file.write("This is my third line")
file.write("This is my fourth line")
file.close()

# %%
file = open("file.txt","w")
file.write("This is my fifth line")                 #all earlier content will be deleted
file.close()

# %%
file = open("file.txt","w")
file.write("This is my first line\n")
file.write("This is my second line\n")
file.write("This is my third line\n")
file.write("This is my fourth line\n")
file.close()

# %%
file = open("file.txt","a")         #append the new line
file.write("This is my fifth line\n")      
file.close()

# %%
#Various ways of printing

file = open("file.txt","r")
for i in file:
    print(i)
# Out:
# This is my first line
#
# This is my second line
#
# This is my third line
#
# This is my fourth line
#
# This is my fifth line

# %%
file.read()                 #Cursor at last position that is why empty string
# Out:
# ''

# %%
file.tell()     #it tells the current position of cursor
# Out:
# 117

# %%
file.seek(0)
# Out:
# 0

# %%
f = open("file.txt","r")
print(f.readline())             #it will only read the first line
f.close()
# Out:
# This is my first line

# %%
f = open("file.txt","r")
print(f.readlines())             #All the lines will be the element of a list
f.close()
# Out:
# ['This is my first line\n', 'This is my second line\n', 'This is my third line\n', 'This is my fourth line\n', 'This is my fifth line\n']

# %%
f = open("file.txt","r")
f.seek(0)           #It will bring cursor to start of the file
print(f.read())     #It will read everything from starting
f.close()
# Out:
# This is my first line
# This is my second line
# This is my third line
# This is my fourth line
# This is my fifth line

# %%
#Creating files, folders using Python
#present working directory -> !pwd

import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Homes\\OneDrive\\Documents\\Coding\\Python\\Learning-python'

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 3026-A728
#
#  Directory of c:\Users\Homes\OneDrive\Documents\Coding\Python\Learning-python
#
# 08-07-2026  15:24    <DIR>          .
# 08-07-2026  19:34    <DIR>          ..
# 09-07-2026  10:10    <DIR>          .git
# 08-07-2026  15:24             7,271 basic.ipynb
# 08-07-2026  15:24            10,379 conditionals.ipynb
# 09-07-2026  10:03               117 file.txt
# 09-07-2026  10:19            12,126 filehandling.ipynb
# 08-07-2026  15:24            37,337 function.ipynb
# 08-07-2026  15:24            17,103 function2.ipynb
# 08-07-2026  15:24            12,705 iterator_generator.ipynb
# 08-07-2026  15:24            13,392 loop.ipynb
# 08-07-2026  15:24             5,809 mutability.ipynb
# 03-04-2026  10:35            16,612 oops.ipynb
# 08-07-2026  15:24            10,424 operator.ipynb
# 08-07-2026  15:24             3,972 README.md
# 08-07-2026  15:24            10,547 typecasting.ipynb
# ...

# %%
os.path.getsize("file.txt")
# Out:
# 117

# %%
os.mkdir("test")

# %%
os.mkdir("test/test1")

# %%
os.mkdir("1/2")         #it will throw an error >> because 1 is not made first
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 os.mkdir("1/2")         #it will throw an error >> because 1 is not made first
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '1/2'

# %%
import os
os.makedirs("1/2/3/4")

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 3026-A728
#
#  Directory of c:\Users\Homes\OneDrive\Documents\Coding\Python\Learning-python
#
# 09-07-2026  10:34    <DIR>          .
# 08-07-2026  19:34    <DIR>          ..
# 09-07-2026  10:35    <DIR>          .git
# 09-07-2026  10:34    <DIR>          1
# 08-07-2026  15:24             7,271 basic.ipynb
# 08-07-2026  15:24            10,379 conditionals.ipynb
# 09-07-2026  10:03               117 file.txt
# 09-07-2026  10:35            15,533 filehandling.ipynb
# 08-07-2026  15:24            37,337 function.ipynb
# 08-07-2026  15:24            17,103 function2.ipynb
# 08-07-2026  15:24            12,705 iterator_generator.ipynb
# 08-07-2026  15:24            13,392 loop.ipynb
# 08-07-2026  15:24             5,809 mutability.ipynb
# 03-04-2026  10:35            16,612 oops.ipynb
# 08-07-2026  15:24            10,424 operator.ipynb
# 08-07-2026  15:24             3,972 README.md
# 09-07-2026  10:33    <DIR>          test
# ...

# %% [markdown]
# os.listdir()

# %%
os.mkdir("feat")

# %%
os.rmdir("feat")        #deleting one directory without any content inside the directory

# %%
os.rmdir("test")            #throw an error as test is not empty
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 os.rmdir("test")            #throw an error as test is not empty
#
# PermissionError: [WinError 5] Access is denied: 'test'

# %%
import shutil
# This will remove '1' and everything contained within it (1, 2, 3, and 4)
shutil.rmtree("1")

# %%
import shutil
shutil.rmtree("test")

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\Homes\\OneDrive\\Documents\\Coding\\Python\\Learning-python'

# %%
os.makedirs("test/test1")

# %%
f=open("c://Users//Homes//OneDrive/Documents//Coding//Python//Learning-python//test//test1//file.txt", "w")

# %%
#Copy the above file in the location>> c://Users//Homes//OneDrive/Documents//Coding//Python//Learning-python
#shutil.copy(src,dst) #src >> source file path, dst >> destination file path

shutil.copy("c://Users//Homes//OneDrive/Documents//Coding//Python//Learning-python//test//test1//file.txt", "c://Users//Homes//OneDrive/Documents//Coding//Python//Learning-python")   #keeps a copy at original source as well
# Out:
# 'c://Users//Homes//OneDrive/Documents//Coding//Python//Learning-python\\file.txt'

# %%
os.mkdir("file_test")
shutil.move("c://Users//Homes//OneDrive/Documents//Coding//Python//Learning-python//file.txt", "c://Users//Homes//OneDrive/Documents//Coding//Python//Learning-python//file_test")   #moves while removing the file from the original source to destination source
# Out:
# 'c://Users//Homes//OneDrive/Documents//Coding//Python//Learning-python//file_test\\file.txt'

# %%
with open("file.txt","w") as f:
    f.write("This is my first line\n")

#with statement insures that the file is closed properly after the block of code is executed.
#important >> free up system resources and avoid issues like data corruption or file lock

# %%
with open("file.txt","r") as f:
   line = f.readline()
   print(line)
# Out:
# This is my first line
