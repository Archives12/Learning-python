# %%
text_content = """
example1
example2
example3
"""

# %%
with open("example.txt", "w") as file:
    file.write(text_content)

# %%
with open("example.txt", "r") as file:
    data = file.read()
print(data)
# Out:
# example1
# example2
# example3
