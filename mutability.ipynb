# %%
#In the memory, a memory block is create with reference name a and value 6.
a = 6
a
# Out:
# 6

# %%
b = "Ajay"
b
# Out:
# 'Ajay'

# %%
b[0]
# Out:
# 'A'

# %%
b[-2]
# Out:
# 'a'

# %%
b[2]
# Out:
# 'a'

# %%
#another type of data container is list
list_cont=[1,2,3,4.5,True, "Ajay"]
list_cont
# Out:
# [1, 2, 3, 4.5, True, 'Ajay']

# %%
list_cont[0]
# Out:
# 1

# %%
type(list_cont)
# Out:
# list

# %%
#mutability(change)
list_cont[5] = "Bijay"
list_cont
# Out:
# [1, 2, 3, 4.5, True, 'Bijay']

# %%
#Objects / conatiners whose state or value can be changed after they are created are called as mutable objects / containers, also called as item assignment.
#List is a type of mutable obejct / supports item assignment.

# String are immutable objects.

b = "pwskills"
b
# Out:
# 'pwskills'

# %%
b[0]
# Out:
# 'p'

# %%
b[1] ="S"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 b[1] ="S"
#
# TypeError: 'str' object does not support item assignment
